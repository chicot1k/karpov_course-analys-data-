# %%
import pandas as pd
 
taxi = pd.read_csv("/content/2_taxi_nyc.csv")
taxi.shape
taxi.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
taxi
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp 01  pcp 06  pcp 24   sd
# ...

# %%
taxi.rename(columns = {'pcp 01':'pcp_01', 'pcp 06': 'pcp_06','pcp 24': 'pcp_24'})
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
taxi.query("borough == 'Manhattan'").shape[0]
# Out:
# 4343

# %%
taxi.borough.value_counts()
# Out:
# Bronx            4343
# Brooklyn         4343
# EWR              4343
# Manhattan        4343
# Queens           4343
# Staten Island    4343
# Name: borough, dtype: int64

# %%
taxi.query('borough == "Brooklyn"')
# Out:
#                  pickup_dt pickup_month   borough  pickups hday  spd   vsb  \
# 1      2015-01-01 01:00:00          Jan  Brooklyn     1519    Y  5.0  10.0
# 8      2015-01-01 02:00:00          Jan  Brooklyn     1229    Y  3.0  10.0
# 15     2015-01-01 03:00:00          Jan  Brooklyn     1601    Y  5.0  10.0
# 22     2015-01-01 04:00:00          Jan  Brooklyn     1390    Y  5.0  10.0
# 29     2015-01-01 05:00:00          Jan  Brooklyn      759    Y  5.0  10.0
# ...                    ...          ...       ...      ...  ...  ...   ...
# 29069  2015-06-30 19:00:00          Jun  Brooklyn      777    N  5.0  10.0
# 29076  2015-06-30 20:00:00          Jun  Brooklyn      817    N  8.0  10.0
# 29083  2015-06-30 21:00:00          Jun  Brooklyn      829    N  7.0  10.0
# 29089  2015-06-30 22:00:00          Jun  Brooklyn      860    N  5.0  10.0
# 29095  2015-06-30 23:00:00          Jun  Brooklyn      990    N  7.0  10.0
#
#        temp  dewp     slp  pcp 01  pcp 06  pcp 24   sd
# ...

# %%
taxi.groupby('borough') \
    .agg({'hday':'count'})
# Out:
#                hday
# borough
# Bronx          4343
# Brooklyn       4343
# EWR            4343
# Manhattan      4343
# Queens         4343
# Staten Island  4343

# %% [markdown]
# Максимальный

# %%
min_pickups = taxi.groupby('borough') \
    .agg({'pickups': 'sum'}) \
    .idxmax()
min_pickups
# Out:
# pickups    Manhattan
# dtype: object

# %%
taxi.groupby('borough', as_index = False) \
    .agg({'pickups': 'sum'}).max()
# Out:
# borough    Staten Island
# pickups         10367841
# dtype: object

# %% [markdown]
# Неправильно!

# %%
taxi.idxmax
# Out:
# <bound method DataFrame.idxmax of                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
# ...

# %% [markdown]
# Среднее значение по группам

# %%
taxi.groupby(['borough','hday']) \
    .agg({'pickups':'mean'})
# Out:
#                         pickups
# borough       hday
# Bronx         N       50.771073
#               Y       48.065868
# Brooklyn      N      534.727969
#               Y      527.011976
# EWR           N        0.023467
#               Y        0.041916
# Manhattan     N     2401.302921
#               Y     2035.928144
# Queens        N      308.899904
#               Y      320.730539
# Staten Island N        1.606082
#               Y        1.497006

# %% [markdown]
# Cортировка

# %%
taxi.groupby(['borough','pickup_month'], as_index = False) \
    .agg({'pickups' : 'sum'}) \
    .sort_values('pickups', ascending = False)
# Out:
#           borough pickup_month  pickups
# 21      Manhattan          Jun  1995388
# 23      Manhattan          May  1888800
# 19      Manhattan          Feb  1718571
# 22      Manhattan          Mar  1661261
# 18      Manhattan          Apr  1648278
# 20      Manhattan          Jan  1455543
# 9        Brooklyn          Jun   482466
# 11       Brooklyn          May   476087
# 6        Brooklyn          Apr   378095
# 10       Brooklyn          Mar   346726
# 7        Brooklyn          Feb   328650
# 8        Brooklyn          Jan   309011
# 27         Queens          Jun   286311
# 29         Queens          May   275893
# 28         Queens          Mar   219561
# 24         Queens          Apr   216857
# 25         Queens          Feb   185695
# 26         Queens          Jan   159211
# 5           Bronx          May    53037
# 3           Bronx          Jun    49006
# 0           Bronx          Apr    34617
# 4           Bronx          Mar    32232
# ...

# %%
def temp_to_celcius(temp):
    Celsius = ((temp-32) *5.0)/(9.0)
    return Celsius

# %%
temp_to_celcius(taxi.temp)
# Out:
# 0        -1.111111
# 1        -1.111111
# 2        -1.111111
# 3        -1.111111
# 4        -1.111111
#            ...
# 29096    23.888889
# 29097    23.888889
# 29098    23.888889
# 29099    23.888889
# 29100    23.888889
# Name: temp, Length: 29101, dtype: float64

# %% [markdown]
# # **Проектная часть урока**

# %%
from pandas.io.parsers.readers import read_csv
hotel = pd.read_csv('/content/bookings.csv',';')
hotel
# Out:
# <ipython-input-109-109b9825f95f>:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   hotel = pd.read_csv('/content/bookings.csv',';')
#                Hotel  Is Canceled  Lead Time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# ...

# %%
hotel.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
def lower_probel(name):
   name = name.lower().replace(' ', '_')
   return name

# %%
lower_probel('Ljlg hds')
# Out:
# 'ljlg_hds'

# %%
hotel.columns.tolist()
# Out:
# ['Hotel',
#  'Is Canceled',
#  'Lead Time',
#  'arrival full date',
#  'Arrival Date Year',
#  'Arrival Date Month',
#  'Arrival Date Week Number',
#  'Arrival Date Day of Month',
#  'Stays in Weekend nights',
#  'Stays in week nights',
#  'stays total nights',
#  'Adults',
#  'Children',
#  'Babies',
#  'Meal',
#  'Country',
#  'Reserved Room Type',
#  'Assigned room type',
#  'customer type',
#  'Reservation Status',
#  'Reservation status_date']

# %%
new=[]
for i in hotel.columns.tolist():
  new.append(lower_probel(i))
new
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_full_date',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'stays_total_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'reserved_room_type',
#  'assigned_room_type',
#  'customer_type',
#  'reservation_status',
#  'reservation_status_date']

# %% [markdown]
# НЕПОНИМАЮ!

# %%
hotel = hotel.rename(columns = lower_probel)

# %%
hotel.query('is_canceled == 0')\
     .country\
     .value_counts()[:20]
# Out:
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# IRL     2543
# ITA     2433
# BEL     1868
# NLD     1717
# USA     1596
# BRA     1394
# CHE     1302
# AUT     1033
# CN      1025
# SWE      797
# POL      704
# CHN      537
# ISR      500
# NOR      426
# RUS      393
# Name: country, dtype: int64

# %%
hotel.groupby('hotel')\
.agg({'stays_total_nights': 'mean'})
# Out:
#               stays_total_nights
# hotel
# City Hotel              2.978142
# Resort Hotel            4.318547

# %%
hotel
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
hotel.query('reserved_room_type !=	assigned_room_type').shape
# Out:
# (14917, 21)

# %%
date=hotel[['arrival_date_month','arrival_date_year','reservation_status']]
date2016 = date.query('arrival_date_year == 2016')
date2016.groupby('arrival_date_month')\
.agg({'reservation_status':'count'}).idxmax
# Out:
# reservation_status    October
# dtype: object

# %%
hotel.query('arrival_date_year == 2016')\
.arrival_date_month\
.value_counts()
# Out:
# October      6203
# May          5478
# April        5428
# September    5394
# June         5292
# August       5063
# March        4824
# July         4572
# November     4454
# February     3891
# December     3860
# January      2248
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# Вытащил сколько поездок в 2016
#
# Вытащил месяца поездок
#
# посчитал

# %% [markdown]
# Вытащил месяца и года
# взял конкретный год
# сгруппировал по месяцам
# посчитал количество в них произвольных элементов

# %%
date=hotel[['arrival_date_month','arrival_date_year','reservation_status']]
date2016 = date.query('arrival_date_year == 2017')
date2016.groupby('arrival_date_month')\
.agg({'reservation_status':'count'}).idxmax()
# Out:
# reservation_status    May
# dtype: object

# %%
hotel.query('hotel == "City Hotel" and is_canceled == 1')\
.groupby('arrival_date_year')\
.arrival_date_month\
.value_counts()
# Out:
# arrival_date_year  arrival_date_month
# 2015               September             1543
#                    October               1321
#                    August                1232
#                    July                   939
#                    December               668
#                    November               301
# 2016               October               1947
#                    June                  1720
#                    September             1567
#                    April                 1539
#                    May                   1436
#                    November              1360
#                    August                1247
#                    March                 1108
#                    December              1072
#                    July                  1043
#                    February               930
#                    January                438
# 2017               May                   2217
#                    April                 1926
# ...

# %%
hotel[['adults', 'children','babies']].describe()
# Out:
#               adults       children         babies
# count  119390.000000  119386.000000  119390.000000
# mean        1.856403       0.103890       0.007949
# std         0.579261       0.398561       0.097436
# min         0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000
# 50%         2.000000       0.000000       0.000000
# 75%         2.000000       0.000000       0.000000
# max        55.000000      10.000000      10.000000

# %%
hotel['adults'].mean()
hotel['children'].mean()
hotel['babies'].mean()
# Out:
# 0.007948739425412514

# %%
hotel['total_kids'] = hotel['babies'] + hotel['children']
hotel.groupby('hotel')\
.agg({'total_kids':'mean'})
# Out:
#               total_kids
# hotel
# City Hotel      0.096311
# Resort Hotel    0.142586
